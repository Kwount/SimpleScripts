# %% [markdown]
# # Frequency dictionary

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
""" Обрабатывает файл и создает частотный словарь (частота повторения слова в тексте) """

import sys
import os
import re

# if len(sys.argv) == 1:
#     print('Нет параметров для запуска!')
#     sys.exit(1)

# work_file = sys.argv[1]
work_file = "analyst_rules.txt"
if os.path.isfile(work_file):
    print('Рабочий файл: ' + work_file)

# читаем файл
file = open(work_file, 'r')
try:
    txt = file.read()
finally:
    file.close()

# выбираем слова через регулярные выражения
p = re.compile("features:([a-zA-Z-']+)")
res = p.findall(txt)

# создаем словарь. Ключ-слово, Значение-частота повторения
lsWord = {}
for key in res:
    if key in lsWord:
        value = lsWord[key]
        lsWord[key] = value + 1
    else:
        lsWord[key] = 1

# создаем список ключей отсортированный по значению словаря lsWord
sorted_keys = sorted(lsWord, key=lambda x: int(lsWord[x]), reverse=True)
file = open(work_file + '_dict.csv', 'a+')
try:
    for key in sorted_keys:
        s = str("{0};{1}\n").format(key, lsWord[key])
        print(s+"\n")
        file.write(s)
    print('Результат записан: ' + work_file + '_dict.csv')
finally:
    file.close()
# Out:
# Рабочий файл: analyst_rules.txt
# RcvSrcExt;2375
#
#
# MsgSize;2264
#
#
# WordCount;1510
#
#
# HasTextOnly;1457
#
#
# UrlNormCount;1434
#
#
# TextLines;1390
#
#
# MultipartNum;1203
#
#
# HtmlTagCount;863
#
#
# NoRealNameTo;848
#
#
# UserCreateTime;518
#
#
# IsPddUser;491
#
#
# RepuserAge;464
#
#
# Karma;432
#
#
# Words;315
#
#
# ImgNum;311
#
#
# Subject;303
#
#
# UrlCount;293
#
#
# UrlCountWithoutMailRu;228
#
#
# FromDomain;209
#
#
# RcptNum;181
#
#
# HasAttach;180
#
#
# UrlsTextSize;172
#
#
# WhitespaceToWordRatio;157
#
#
# SubjectWordCount;148
#
#
# NumberCount;148
#
#
# RcvSrc;148
#
#
# LinesToWordsRatio;143
#
#
# HasNoAttach;124
#
#
# FilesExtensions;110
#
#
# IpCategory;104
#
#
# FromRealNameWordCount;102
#
#
# AttachAllCount;101
#
#
# Word;85
#
#
# UserAge;82
#
#
# FromLocalPart;81
#
#
# NoSubject;80
#
#
# FromRealName;80
#
#
# NoBodyTag;79
#
#
# HtmlTags;79
#
#
# IsFromGoogle;78
#
#
# NoHtmlTag;77
#
#
# AbfCitiesPerMonthNum;75
#
#
# MailRuTo;74
#
#
# WordsOtherRatio;74
#
#
# DomainRepipAge;70
#
#
# NoTo;70
#
#
# From;66
#
#
# MpopUserId;66
#
#
# NoUserAgent;65
#
#
# PartsFilenames;63
#
#
# AttachOfficeCount;62
#
#
# NoRealNameFrom;61
#
#
# SubjectLen;60
#
#
# HasShortUrl;59
#
#
# SubjectNumbersCount;57
#
#
# HasImageUrl;53
#
#
# EnvelopeFromDomain;53
#
#
# IpAge;50
#
#
# MsgIdLocalPart;50
#
#
# ExternalImgNum;49
#
#
# WordsMixedRatio;49
#
#
# DotCount;48
#
#
# IsAutoreg;46
#
#
# DkimDomain;45
#
#
# Helo;45
#
#
# AuthenticatedDomain;44
#
#
# SrcIp;43
#
#
# ImapSubSrc;43
#
#
# FromDomainCategory;41
#
#
# IsFromRambler;40
#
#
# DkimDomainRepipAge;40
#
#
# EmailsCountInBody;40
#
#
# IsFromYandex;40
#
#
# HtmlUniqueTagCount;38
#
#
# UrlsRawHashString;35
#
#
# SPF;35
#
#
# Date;33
#
#
# EngRealNameFrom;31
#
#
# WordOtherCount;31
#
#
# ShingleTextSize;31
#
#
# MsgIdDomain;29
#
#
# HeloInMsgId;28
#
#
# AttachArchiveCount;28
#
#
# ToRealName;28
#
#
# SmtpFeGoodSR;26
#
#
# IsFromFreeMail;26
#
#
# OneWordSubject;26
#
#
# WhitespaceCount;26
#
#
# SubjectWord;25
#
#
# HasFreeHosting;25
#
#
# SubjectWordMixedCount;24
#
#
# HasDifferentFromAndReply;22
#
#
# SimpleType;22
#
#
# ToRealNameInToLocalPart;22
#
#
# To;21
#
#
# SubjectWords;20
#
#
# LastHelo;20
#
#
# RepIpComplRatioByLastWeek;19
#
#
# GeoCode;19
#
#
# IsFromOtherMbp;19
#
#
# InvalidFrom;19
#
#
# WordMixedCount;18
#
#
# Has;17
#
#
# AbfIpWasChanged;17
#
#
# ToEmailInBody;16
#
#
# AbfCityWasChanged;16
#
#
# SourceTextSize;15
#
#
# AbfCountriesPerMonthNum;15
#
#
# NoRealNameReplyTo;13
#
#
# XMailerName;13
#
#
# RamblerSmtp;13
#
#
# HasPhotoHosting;13
#
#
# RepIpComplRatioByLastMonth;13
#
#
# AttachOtherCount;13
#
#
# RepuserMissedHits;12
#
#
# WhitespaceRatio;12
#
#
# HasSuspEspUrl;12
#
#
# ShortUrlCount;11
#
#
# DotRatio;11
#
#
# EmailsCountInCcHeader;11
#
#
# ReplyTo;11
#
#
# ReplyToRealName;11
#
#
# EmailsCountInToHeader;11
#
#
# FromMatchesWithUrl;10
#
#
# MsgIdDomainNotEqualFromDomain;10
#
#
# SpfDomain;10
#
#
# GetSubjectEncoding;9
#
#
# AttachMultimediaCount;8
#
#
# BodyUpperLowerCaseRatio;8
#
#
# RepIpProbableSpamRatioByLastWeek;8
#
#
# FromEndsWithYear;8
#
#
# HtmlTagsUnknownCount;8
#
#
# ToUndisclosed;8
#
#
# AutoregInfoClustersHeaderValue;8
#
#
# FromRealNameInFromLocalPart;8
#
#
# UrlsHashString;8
#
#
# ReplyInSubject;7
#
#
# RepIpSpamRatioByLastWeek;7
#
#
# ForwardingSubject;7
#
#
# HasUnsubscribeUrl;7
#
#
# HasBcc;7
#
#
# CutUrlsRawOnly;7
#
#
# NumbersToZeroRatio;6
#
#
# Ptr;6
#
#
# FromRealNameLen;6
#
#
# AbfCountryWasChanged;6
#
#
# AbfAuthFromNewCountry;6
#
#
# HasFromRealName;6
#
#
# FreeHostingUrlCount;6
#
#
# IsExecNameInArchive;5
#
#
# UrlInListUnsubscribe;5
#
#
# ToLocalPart;5
#
#
# ToRealNameInSubject;5
#
#
# MailRuFrom;5
#
#
# FilesInArchiveNum;5
#
#
# FirstLevelFromDomain;5
#
#
# FakeReplyInSubject;5
#
#
# EmailInToRealName;5
#
#
# IsRmspamProfile;5
#
#
# HtmlFingerprint;5
#
#
# AbfIsFastIpChange;5
#
#
# HeaderNum;5
#
#
# MessageId;5
#
#
# SenderPtr;4
#
#
# EnvelopeFromMatchesWithUrl;4
#
#
# SubjectWordOtherCount;4
#
#
# DKIM;4
#
#
# IsSngCountry;4
#
#
# MsgGetHashAttach;4
#
#
# EmailsCountInBccHeader;4
#
#
# NoFrom;4
#
#
# HtmlTagsKnown;4
#
#
# ToDomain;4
#
#
# EnvelopeFromDomainRepipAge;3
#
#
# ReturnPath;3
#
#
# NumbersToTextRatio;3
#
#
# CtMultipartSpamPattern;3
#
#
# MobileMailRu;3
#
#
# RepuserMailCmplRatioBy;3
#
#
# CTEId;3
#
#
# CtypeId;3
#
#
# UserAgent;3
#
#
# AttachWithoutExtenstionsCount;3
#
#
# AttachExecutableCount;3
#
#
# PhotoHostingUrlCount;3
#
#
# IsReplyToFreeMail;3
#
#
# UrlsInSubject;3
#
#
# EmailInSubject;3
#
#
# RepIpSpamRatioByLastMonth;3
#
#
# MultipartPartCount;3
#
#
# RemoteOS;3
#
#
# ReplySubject;3
#
#
# IsFromMailru;2
#
#
# EnvelopeFrom;2
#
#
# FromMailerDaemon;2
#
#
# IsEnglishMessage;2
#
#
# IsComplaint;2
#
#
# UrlsHash;2
#
#
# MsgTypeRepipAge;2
#
#
# UrlsInFromRealName;2
#
#
# WordsToUrlsRatio;2
#
#
# SubjectUtf;2
#
#
# FromEmailInBody;2
#
#
# MailRuMxsMsgId;2
#
#
# MailRuFeMsgId;2
#
#
# OneWidthImagesNum;2
#
#
# IsEnvelopeFromFreeMail;2
#
#
# EmailEndWithNum;2
#
#
# RepFromDomainTrapHitsByLastDay;2
#
#
# AttachWebCount;2
#
#
# UrlsInFromDomain;2
#
#
# IsFromYahoo;2
#
#
# Badnet;2
#
#
# IsFromHotmail;2
#
#
# RepuserMissedRatio;2
#
#
# AbfLastAuthCountry;2
#
#
# BirthDateInFromLocalpart;2
#
#
# AbfCitiesPerDayNum;2
#
#
# SrcNet;2
#
#
# HasIpUrls;2
#
#
# RepFromDomainTotalHitsByLastDay;2
#
#
# UrlEncodedImg;1
#
#
# FirstLevelReplyToDomain;1
#
#
# SameEmailToAndSubject;1
#
#
# RepIpProbableSpamRatioByLastMonth;1
#
#
# TermTextSize;1
#
#
# RepIpInvRatioByLastWeek;1
#
#
# GidRepipAge;1
#
#
# NotMailRuEmailInBody;1
#
#
# ImgLinkExtesionCount;1
#
#
# HasCTEncodedHeader;1
#
#
# AllAppTypes;1
#
#
# HasScriptTags;1
#
#
# CapsLockOnlySubject;1
#
#
# RepFromDomainTotalHitsByLastHour;1
#
#
# EmailsCountInFromHeader;1
#
#
# MsgIdNoDomain;1
#
#
# AttachUrlCount;1
#
#
# AuthenticatedSender;1
#
#
# IsYahooIp;1
#
#
# FromDomainLevelCount;1
#
#
# RepIpSpamRatioByLastDay;1
#
#
# HasDifferentFromAndReplyEmails;1
#
#
# AbfCountriesPerDayNum;1
#
#
# FromInvalidChars;1
#
#
# ToInvalidChars;1
#
#
# XMailer;1
#
#
# RepIpHamHitsByLastWeek;1
#
#
# RepIpHamHitsByLastMonth;1
#
#
# FromMailToSuspDomain;1
#
#
# PostmasterMsgTypeRepipAge;1
#
#
# RepuserSpamHits;1
#
#
# HtmlTagsKnownCount;1
#
#
# RepIpTotalHitsByLastWeek;1
#
#
# RepuserTotalHitsBy;1
#
#
# SubjectMixedOnly;1
#
#
# RepIpComplRatioByLastHour;1
#
#
# UrlFotoMyMail;1
#
#
# RepuserMailSpamHitsByDay;1
#
#
# FromRealnameSuspPattern;1
#
#
# ShortWithUrls;1
#
#
# IsMarosnetIp;1
#
#
# EmptyTo;1
#
#
# InvalidReplyTo;1
#
#
# MailUserAgentType;1
#
#
# RepIpComplHitsByLastWeek;1
#
#
# FromAndDkimDomainMismtach;1
#
#
# DkimDomainCategory;1
#
#
# ExclamationMarkInSubject;1
#
#
# GetEmailsFromBody;1
#
#
# CloudYandexUrl;1
#
#
# BoundaryFromHeader;1
#
#
# RepIpComplRatioByLastDay;1
#
#
# EmptyFrom;1
#
#
# ShortUrlMatchListUnsubscribe;1
#
#
# NoRealOrganization;1
#
#
# UnavailableInReceived;1
#
#
# RepFromDomainSpamHitsByLastWeek;1
#
#
# AbfTable;1
#
#
# IsFromAol;1
#
#
# Результат записан: analyst_rules.txt_dict.csv
